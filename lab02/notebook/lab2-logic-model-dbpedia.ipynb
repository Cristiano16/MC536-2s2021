# %% [markdown]
# # Laboratório 2

# %% [markdown]
# ## Tarefa 1
#
# ### Carregue o nó de Tenda dos Milagres (da versão em inglês Tent of Miracles) em Python e mostre o conteúdo JSON.

# %%
import io
import requests
import json

# %%
url_template = "http://dbpedia.org/data/{concept}.{format}"

concept = "Tent of Miracles (novel)"
format = "jsod"

concept = concept.replace(" ", "_")

url = url_template.replace("{concept}", concept)\
                  .replace("{format}", format)

data = requests.get(url)
js = data.json()
print(json.dumps(js, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Tent_of_Miracles_(novel)"
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "Tent of Miracles (novel)",
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/French_New_Wave"
#                }
#             },
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Modernist_novels"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/ontology/WrittenWork"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:According_to_whom"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Tent of Miracles (Portuguese: Tenda dos Milagres) is a Brazilian Modernist novel. It was written by Jorge Amado in 1967 and published the following year. It was later adapted to a 1977 Cinema Novo (Nouvelle Vague) film by director/screenplay writer Nelson Pereira dos Santos.",
#             "http://dbpedia.org/ontology/abstract": "La bottega dei miracoli \u00e8 un romanzo di Jorge Amado pubblicato nel 1960. Come altri romanzi dell&#39;autore (ad esempio Tieta d&#39;Agreste e Teresa Batista) \u00e8 un testo composito, con un intreccio zigzagante fra analessi e prolessi, con mutamenti di voci narranti ed inserti di materiale eterogeneo.\u00c8 possibile che l&#39;evento scatenante del racconto (la visita del famoso scienziato) sia stato ispirato dall&#39;esperienza vissuta; in quello stesso 1960, infatti, Jean Paul Sartre e Simone De Beauvoir visitarono il Brasile su invito dello stesso Amado: la visita divenne un evento mediatico, celebrato in numerose manifestazioni istituzionali.",
#             "http://dbpedia.org/property/pubDate": "1969",
#             "http://dbpedia.org/property/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://rdf.freebase.com/ns/m.02xrs4"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "974212123",
#             "http://dbpedia.org/property/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://dbpedia.org/ontology/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/name": "Tenda dos Milagres",
#             "http://dbpedia.org/property/englishPubDate": "1971",
#             "http://dbpedia.org/ontology/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/property/name": "Tent of Miracles",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Novel"
#                }
#             },
#             "http://dbpedia.org/property/titleOrig": "Tenda dos Milagres",
#             "http://dbpedia.org/ontology/publisher": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/ontology/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)?oldid=974212123&ns=0"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "5253",
#             "http://purl.org/dc/elements/1.1/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageID": "623351",
#             "http://dbpedia.org/property/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/caption": "First edition",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }

# %% [markdown]
# ## Tarefa 2
# ### Recupere via Python e mostre o autor de Tenda dos Milagres?

# %%
writer = js["d"]["results"][0]["http://dbpedia.org/ontology/author"]["__deferred"]["uri"]
print("Autor de Tent of Miracles: " + writer)
# Out:
# Autor de Tent of Miracles: http://dbpedia.org/resource/Jorge_Amado

# %% [markdown]
# ## Tarefa 3
# ### Quais os termos usados para Aspirina (consulta JSON/MeSH em Python)?

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/descriptor?label={concept}&match={match}&limit={limit}"

concept = "Aspirin"
match = "exact"
limit = "10"

concept = concept.replace(" ", "%20")

url = url_template.replace("{concept}", concept)\
                  .replace("{match}", match)\
                  .replace("{limit}", limit)

data = requests.get(url)
json_mi = data.json()
print(json.dumps(json_mi, indent=3))
# Out:
# [
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/D001241",
#       "label": "Aspirin"
#    }
# ]

# %%
#Seleciona somente o codigo do url retornada
resourse = json_mi[0]["resource"]
bar = str.rindex(resourse, "/")
code = resourse[bar+1:]
print("Código do recurso: " + code)
# Out:
# Código do recurso: D001241

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/details?descriptor={code}"

url = url_template.replace("{code}", code)

data = requests.get(url)
json_mid = data.json()
print(json.dumps(json_mid["terms"], indent=3))
# Out:
# [
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003713",
#       "label": "Aspirin",
#       "preferred": true
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003714",
#       "label": "2-(Acetyloxy)benzoic Acid",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003712",
#       "label": "Acetylsalicylic Acid",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003721",
#       "label": "Acetysal",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003722",
#       "label": "Acylpyrin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003711",
#       "label": "Aloxiprimum",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003723",
#       "label": "Colfarit",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003715",
#       "label": "Dispril",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003719",
#       "label": "Easprin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003724",
#       "label": "Ecotrin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003725",
#       "label": "Endosprin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003726",
#       "label": "Magnecyl",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003727",
#       "label": "Micristin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003717",
#       "label": "Polopirin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003728",
#       "label": "Polopiryna",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003716",
#       "label": "Solprin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003718",
#       "label": "Solupsan",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003720",
#       "label": "Zorprin",
#       "preferred": false
#    }
# ]

# %% [markdown]
# ## Tarefa 4
# ### Escolha algum lugar no OpenStreetMap e elabore a mesma sequência de três chamadas de serviços para o seu conceito.

# %%
url_template = "http://nominatim.openstreetmap.org/search?format={format}&q={query}"
format = "json"
query = "Deadhorse"

url = url_template.replace("{format}", format)\
                  .replace("{query}", query)

data = requests.get(url)
town_ref = data.json()
print(json.dumps(town_ref, indent=3))
# Out:
# [
#    {
#       "place_id": 340742,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "node",
#       "osm_id": 150918086,
#       "boundingbox": [
#          "70.1606973",
#          "70.2406973",
#          "-148.4998151",
#          "-148.4198151"
#       ],
#       "lat": "70.2006973",
#       "lon": "-148.4598151",
#       "display_name": "Deadhorse, North Slope, Alaska, United States",
#       "class": "place",
#       "type": "town",
#       "importance": 0.4389652785939945,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//poi_place_town.p.20.png"
#    },
#    {
#       "place_id": 175214057,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 370666378,
#       "boundingbox": [
#          "39.8996385",
#          "39.911341",
#          "-105.91824",
#          "-105.891628"
#       ],
#       "lat": "39.9042477",
#       "lon": "-105.9085013",
#       "display_name": "Deadhorse, Grand County, Colorado, United States",
#       "class": "highway",
#       "type": "track",
#       "importance": 0.21
#    },
#    {
#       "place_id": 251254618,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 828894630,
#       "boundingbox": [
#          "39.9067538",
#          "39.9070389",
#          "-105.8833417",
#          "-105.882972"
#       ],
#       "lat": "39.9068898",
#       "lon": "-105.8831476561513",
#       "display_name": "Deadhorse, West St. Louis Creek Rd., Grand County, Colorado, United States",
#       "class": "amenity",
#       "type": "parking",
#       "importance": 0.11100000000000002
#    }
# ]

# %%
print(town_ref[0]["osm_id"])
# Out:
# 150918086

# %%
url_template = "https://api.openstreetmap.org/api/0.6/{element_type}/{id}.{format}"

element_type = "node" # types: node, way, or relation
id = str(town_ref[0]["osm_id"])
format = "json"

url = url_template.replace("{element_type}", element_type)\
                  .replace("{id}", id)\
                  .replace("{format}", format)

data = requests.get(url)
town_node = data.json()
print(json.dumps(town_node, indent=3))
# Out:
# {
#    "version": "0.6",
#    "generator": "CGImap 0.8.5 (2205226 spike-07.openstreetmap.org)",
#    "copyright": "OpenStreetMap and contributors",
#    "attribution": "http://www.openstreetmap.org/copyright",
#    "license": "http://opendatacommons.org/licenses/odbl/1-0/",
#    "elements": [
#       {
#          "type": "node",
#          "id": 150918086,
#          "lat": 70.2006973,
#          "lon": -148.459815,
#          "timestamp": "2021-08-10T01:25:53Z",
#          "version": 7,
#          "changeset": 109433203,
#          "user": "Korgi1",
#          "uid": 10114937,
#          "tags": {
#             "ele": "15",
#             "gnis:Class": "Populated Place",
#             "gnis:County": "North Slope",
#             "gnis:County_num": "185",
#             "gnis:id": "1866941",
#             "gnis:ST_alpha": "AK",
#             "gnis:ST_num": "02",
#             "import_uuid": "bb7269ee-502a-5391-8056-e3ce0e66489c",
#             "is_in": "North Slope,Alaska,Alaska,AK,USA",
#             "name": "Deadhorse",
#             "place": "town",
#             "population": "50",
#             "wikidata": "Q605671",
#             "wikipedia": "en:Deadhorse, Alaska"
#          }
#       }
#    ]
# }

# %%
print(town_node["elements"][0]["tags"]["wikipedia"])
# Out:
# en:Deadhorse, Alaska

# %%
url_template = "http://dbpedia.org/data/{concept}.{format}"
concept = town_node["elements"][0]["tags"]["wikipedia"].replace(" ", "_")\
                                                        .replace("en:", "")
format = "jsod"

url = url_template.replace("{concept}", concept)\
                  .replace("{format}", format)

data = requests.get(url)
town_dbpedia = data.json()
print(json.dumps(town_dbpedia, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Deadhorse,_Alaska"
#             },
#             "http://dbpedia.org/property/blank1Info": "1866941",
#             "http://dbpedia.org/property/maySnowInch": "2.21",
#             "http://dbpedia.org/property/julAvgRecordHighF": "74",
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:US_Census_population"
#                }
#             },
#             "http://dbpedia.org/property/augPrecipitationInch": "1.37",
#             "http://dbpedia.org/property/augAvgRecordLowF": "28.9",
#             "http://dbpedia.org/ontology/wikiPageID": "2194130",
#             "http://dbpedia.org/property/febSnowInch": "2.09",
#             "http://dbpedia.org/property/sepAvgRecordHighF": "59.4",
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Key_West"
#                }
#             },
#             "http://dbpedia.org/property/novHighF": "8.300000000000001",
#             "http://dbpedia.org/property/febRecordLowF": "\u221257",
#             "http://dbpedia.org/ontology/abstract": "Deadhorse est une ville d&#39;Alaska aux \u00c9tats-Unis appartenant au Borough de North Slope, pr\u00e8s de l&#39;Oc\u00e9an Arctique. C&#39;est une ville essentiellement tourn\u00e9e vers les fournitures et le logement des personnes qui travaillent sur les installations p\u00e9troli\u00e8res de Prudhoe Bay. Elle est desservie par la Dalton Highway et par un a\u00e9roport. Les installations de Deadhorse se composent de b\u00e2timents pr\u00e9fabriqu\u00e9s, transport\u00e9s sous forme de modules par des avions cargo, et les voies d&#39;acc\u00e8s ne sont pas goudronn\u00e9es. Il existe toutefois quelques h\u00e9bergements limit\u00e9s pour les touristes, m\u00eame si sa vocation n&#39;est pas du tout touristique et se limite \u00e0 l&#39;activit\u00e9 industrielle locale : les forages des puits p\u00e9troliers, et l&#39;acheminement du p\u00e9trole par l&#39;Ol\u00e9oduc trans-Alaska. Son nom proviendrait d&#39;une compagnie de transports la Dead Horse Haulers qui travaillait \u00e0 cet endroit \u00e0 la fin des ann\u00e9es soixante. Par contre, on ne sait pas d&#39;o\u00f9 cette entreprise tenait son nom.",
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/class/yago/Location100027167"
#                }
#             },
#             "http://dbpedia.org/property/marSnowInch": "0.98",
#             "http://dbpedia.org/property/decHighF": "\u22122.7",
#             "http://dbpedia.org/property/janAvgRecordHighF": "21.2",
#             "http://dbpedia.org/property/novRecordHighF": "37",
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Unincorporated_communities_in_Alaska"
#                }
#             },
#             "http://dbpedia.org/property/yearAvgRecordLowF": "-46.4",
#             "http://dbpedia.org/property/blank1Name": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Geographic_Names_Information_System"
#                }
#             },
#             "http://dbpedia.org/property/augSnowInch": "0.12",
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://sws.geonames.org/5860399/"
#                }
#             },
#             "http://dbpedia.org/property/decSnowInch": "2.09",
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "1022134499",
#             "http://dbpedia.org/property/novMeanF": "2",
#             "http://dbpedia.org/property/subdivisionName": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Alaska"
#                }
#             },
#             "http://dbpedia.org/property/sepMeanF": "35.1",
#             "http://dbpedia.org/property/sepRecordLowF": "1",
#             "http://dbpedia.org/ontology/utcOffset": "-9",
#             "http://dbpedia.org/property/source": "Weather Atlas",
#             "http://www.w3.org/2000/01/rdf-schema#label": "Deadhorse, Alaska",
#             "http://dbpedia.org/property/location": "Deadhorse, Alaska",
#             "http://dbpedia.org/property/junRecordLowF": "18",
#             "http://dbpedia.org/property/novLowF": "\u22124.2",
#             "http://dbpedia.org/property/aprAvgRecordLowF": "-25.6",
#             "http://dbpedia.org/property/yearAvgRecordHighF": "77.09999999999999",
#             "http://dbpedia.org/property/imageCaption": "Aerial view of Deadhorse, March 2007",
#             "http://dbpedia.org/property/utcOffset": "-9",
#             "http://dbpedia.org/property/subdivisionType": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/List_of_sovereign_states"
#                }
#             },
#             "http://dbpedia.org/property/julAvgRecordLowF": "32.6",
#             "http://dbpedia.org/property/augHighF": "49.7",
#             "http://dbpedia.org/property/febLowF": "\u221221.1",
#             "http://dbpedia.org/property/julRecordHighF": "85",
#             "http://dbpedia.org/property/octAvgRecordLowF": "-9.199999999999999",
#             "http://dbpedia.org/property/elevationFt": "49",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#lat": "70.20555877685547",
#             "http://dbpedia.org/property/febAvgRecordHighF": "19.5",
#             "http://dbpedia.org/property/junMeanF": "40.3",
#             "http://dbpedia.org/property/augLowF": "38.1",
#             "http://dbpedia.org/property/aprPrecipitationInch": "0.21",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Community"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageExternalLink": {
#                "__deferred": {
#                   "uri": "http://www.prudhoebay.com/communities_Deadhorse.htm"
#                }
#             },
#             "http://dbpedia.org/property/febMeanF": "-14.4",
#             "http://dbpedia.org/property/leaderTitle": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Alaska_Senate"
#                }
#             },
#             "http://dbpedia.org/property/decAvgRecordHighF": "21.9",
#             "http://www.w3.org/2000/01/rdf-schema#comment": "\u0414\u0435\u0434\u0445\u043e\u0440\u0441 \u2014 \u043d\u0435\u043c\u0443\u043d\u0456\u0446\u0456\u043f\u0430\u043b\u044c\u043d\u0430 \u0442\u0435\u0440\u0438\u0442\u043e\u0440\u0456\u044f \u0432 \u043e\u043a\u0440\u0443\u0437\u0456 , \u0410\u043b\u044f\u0441\u043a\u0430, \u0421\u0428\u0410, \u0449\u043e \u0440\u043e\u0437\u0442\u0430\u0448\u043e\u0432\u0443\u0454\u0442\u044c\u0441\u044f \u0432\u0437\u0434\u043e\u0432\u0436 , \u043f\u043e\u0431\u043b\u0438\u0437\u0443 \u041f\u0456\u0432\u043d\u0456\u0447\u043d\u043e\u0433\u043e \u041b\u044c\u043e\u0434\u043e\u0432\u0438\u0442\u043e\u0433\u043e \u043e\u043a\u0435\u0430\u043d\u0443. \u041c\u0456\u0441\u0442\u043e \u0441\u043a\u043b\u0430\u0434\u0430\u0454\u0442\u044c\u0441\u044f, \u043f\u0435\u0440\u0435\u0432\u0430\u0436\u043d\u043e, \u0437 \u043a\u043e\u043c\u043f\u043b\u0435\u043a\u0441\u0443 \u0431\u0443\u0434\u0456\u0432\u0435\u043b\u044c \u0434\u043b\u044f \u043f\u0440\u0430\u0446\u0456\u0432\u043d\u0438\u043a\u0456\u0432 \u0442\u0430 \u043a\u043e\u043c\u043f\u0430\u043d\u0456\u0439, \u044f\u043a\u0456 \u043f\u0440\u0430\u0446\u044e\u044e\u0442\u044c \u043d\u0430 \u0434\u043e\u0432\u043a\u043e\u043b\u0438\u0448\u043d\u0456\u0445 \u043d\u0430\u0444\u0442\u043e\u0432\u0438\u0445 \u0440\u043e\u0434\u043e\u0432\u0438\u0449\u0430\u0445 \u041f\u0440\u0430\u0434\u0445\u043e-\u0411\u0435\u0439. \u0412 \u0414\u0435\u0434\u0445\u043e\u0440\u0441 \u043c\u043e\u0436\u043d\u0430 \u043f\u043e\u0442\u0440\u0430\u043f\u0438\u0442\u0438 \u043f\u043e \u0437 \u0424\u0435\u0440\u0431\u0430\u043d\u043a\u0441\u0430 \u0430\u0431\u043e \u0447\u0435\u0440\u0435\u0437 . \u0414\u043e\u0441\u0442\u0443\u043f\u043d\u0438\u0439 \u0434\u043b\u044f \u043e\u0431\u043c\u0435\u0436\u0435\u043d\u043e\u0433\u043e \u0432\u0456\u0434\u0432\u0456\u0434\u0443\u0432\u0430\u043d\u043d\u044f \u0442\u0443\u0440\u0438\u0441\u0442\u0430\u043c\u0438. \u041f\u043e\u0441\u0442\u0456\u0439\u043d\u0435 \u043d\u0430\u0441\u0435\u043b\u0435\u043d\u043d\u044f \u0432\u0430\u0440\u0456\u044e\u0454\u0442\u044c\u0441\u044f \u0432\u0456\u0434 25 \u0434\u043e 50 \u043e\u0441\u0456\u0431. \u041a\u0456\u043b\u044c\u043a\u0456\u0441\u0442\u044c \u0442\u0438\u043c\u0447\u0430\u0441\u043e\u0432\u0438\u0445 \u043c\u0435\u0448\u043a\u0430\u043d\u0446\u0456\u0432, \u043d\u0430\u0439\u043c\u0430\u043d\u0438\u0445 \u0440\u0456\u0437\u043d\u0438\u043c\u0438 \u043c\u0456\u0441\u0446\u0435\u0432\u0438\u043c\u0438 \u0444\u0456\u0440\u043c\u0430\u043c\u0438, \u043c\u043e\u0436\u0435 \u043f\u0435\u0440\u0435\u0432\u0438\u0449\u0443\u0432\u0430\u0442\u0438 3000. \u0414\u0435\u0434\u0445\u043e\u0440\u0441 \u043f\u043e\u043a\u0430\u0437\u0430\u043d\u0438\u0439 \u0432 \u0442\u0440\u0435\u0442\u044c\u043e\u043c\u0443 \u0442\u0430 \u0447\u0435\u0442\u0432\u0435\u0440\u0442\u043e\u043c\u0443 \u0441\u0435\u0437\u043e\u043d\u0430\u0445 \u0440\u0435\u0430\u043b\u0456\u0442\u0456-\u0448\u043e\u0443 , \u043f\u043e\u043a\u0430\u0437\u0430\u043d\u043e\u043c\u0443 \u043d\u0430 .",
#             "http://dbpedia.org/property/junRecordHighF": "82",
#             "http://dbpedia.org/property/junLowF": "34.3",
#             "http://dbpedia.org/property/junAvgRecordHighF": "69.59999999999999",
#             "http://dbpedia.org/property/febPrecipitationInch": "0.13",
#             "http://dbpedia.org/property/janLowF": "\u221220.8",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Deadhorse,_Alaska"
#                }
#             },
#             "http://dbpedia.org/property/imageSkyline": "Deadhorse Alaska aerial view.jpg",
#             "http://dbpedia.org/property/marRecordLowF": "\u221254",
#             "http://dbpedia.org/property/sepPrecipitationInch": "0.64",
#             "http://dbpedia.org/property/julPrecipitationInch": "1",
#             "http://dbpedia.org/property/sepHighF": "39.4",
#             "http://dbpedia.org/property/mayAvgRecordLowF": "-2.6",
#             "http://dbpedia.org/property/mayRecordLowF": "\u221219",
#             "http://dbpedia.org/property/augRecordLowF": "23",
#             "http://dbpedia.org/property/date": "July 2016",
#             "http://dbpedia.org/property/marAvgRecordLowF": "-41.4",
#             "http://dbpedia.org/property/julHighF": "55.1",
#             "http://dbpedia.org/property/decAvgRecordLowF": "-37.7",
#             "http://dbpedia.org/property/mayHighF": "28.5",
#             "http://dbpedia.org/property/aprRecordHighF": "43",
#             "http://dbpedia.org/property/febRecordHighF": "40",
#             "http://dbpedia.org/property/pushpinMap": "Alaska",
#             "http://dbpedia.org/property/pushpinLabelPosition": "bottom",
#             "http://dbpedia.org/property/janSnowInch": "1.42",
#             "http://dbpedia.org/property/junAvgRecordLowF": "26.5",
#             "http://dbpedia.org/property/precipitationColour": "green",
#             "http://xmlns.com/foaf/0.1/depiction": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/Deadhorse_Alaska_aerial_view.jpg"
#                }
#             },
#             "http://dbpedia.org/property/marHighF": "\u22126.6",
#             "http://dbpedia.org/property/janPrecipitationInch": "0.25",
#             "http://dbpedia.org/property/timezoneDst": "AKDT",
#             "http://dbpedia.org/property/octRecordHighF": "50",
#             "http://dbpedia.org/property/singleLine": "Y",
#             "http://dbpedia.org/property/pushpinRelief": "yes",
#             "http://dbpedia.org/property/augRecordHighF": "82",
#             "http://dbpedia.org/property/novAvgRecordHighF": "25",
#             "http://dbpedia.org/property/decLowF": "\u221215.0",
#             "http://dbpedia.org/property/octLowF": "13.7",
#             "http://dbpedia.org/property/mayLowF": "19.5",
#             "http://dbpedia.org/ontology/subdivision": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Alaska"
#                }
#             },
#             "http://dbpedia.org/property/julSnowInch": "0",
#             "http://dbpedia.org/property/mayMeanF": "24",
#             "http://dbpedia.org/property/janRecordLowF": "\u221262",
#             "http://dbpedia.org/property/utcOffsetDst": "-8",
#             "http://dbpedia.org/property/junSnowInch": "0.79",
#             "http://dbpedia.org/property/junHighF": "46.2",
#             "http://dbpedia.org/property/leaderName": "Donny Olson",
#             "http://dbpedia.org/property/novSnowInch": "2.01",
#             "http://xmlns.com/foaf/0.1/name": "Deadhorse, Alaska",
#             "http://dbpedia.org/property/febHighF": "\u22127.7",
#             "http://dbpedia.org/property/octAvgRecordHighF": "36.8",
#             "http://dbpedia.org/property/marRecordHighF": "42",
#             "http://dbpedia.org/property/julMeanF": "47.8",
#             "http://dbpedia.org/property/aprHighF": "10.3",
#             "http://dbpedia.org/property/mayRecordHighF": "55",
#             "http://dbpedia.org/ontology/elevation": "14.9352",
#             "http://dbpedia.org/property/snowColour": "green",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#long": "-148.5116729736328",
#             "http://dbpedia.org/property/decRecordLowF": "\u221252",
#             "http://dbpedia.org/property/janRecordHighF": "40",
#             "http://dbpedia.org/property/julRecordLowF": "28",
#             "http://dbpedia.org/property/janAvgRecordLowF": "-41.1",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#geometry": "POINT(-148.51167297363 70.205558776855)",
#             "http://dbpedia.org/property/decMeanF": "-8.9",
#             "http://dbpedia.org/property/octHighF": "23.9",
#             "http://dbpedia.org/property/marMeanF": "-13.5",
#             "http://dbpedia.org/ontology/wikiPageLength": "17849",
#             "http://dbpedia.org/property/octRecordLowF": "\u221230",
#             "http://dbpedia.org/property/janHighF": "\u22128.2",
#             "http://dbpedia.org/property/sepRecordHighF": "70",
#             "http://dbpedia.org/property/janMeanF": "-14.5",
#             "http://dbpedia.org/ontology/politicalLeader": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Deadhorse,_Alaska__PoliticalFunction__2"
#                }
#             },
#             "http://dbpedia.org/property/marPrecipitationInch": "0.14",
#             "http://dbpedia.org/property/decPrecipitationInch": "0.36",
#             "http://dbpedia.org/property/settlementType": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Unincorporated_area"
#                }
#             },
#             "http://dbpedia.org/property/aprAvgRecordHighF": "30.9",
#             "http://dbpedia.org/property/decRecordHighF": "39",
#             "http://dbpedia.org/property/mayPrecipitationInch": "0.3",
#             "http://dbpedia.org/ontology/type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Unincorporated_area"
#                }
#             },
#             "http://dbpedia.org/property/junPrecipitationInch": "0.57",
#             "http://dbpedia.org/property/marAvgRecordHighF": "17",
#             "http://dbpedia.org/ontology/timeZone": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Alaska_Time_Zone"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Deadhorse,_Alaska?oldid=1022134499&ns=0"
#                }
#             },
#             "http://dbpedia.org/property/novAvgRecordLowF": "-22.7",
#             "http://dbpedia.org/property/octPrecipitationInch": "0.4",
#             "http://www.georss.org/georss/point": "70.20555555555555 -148.51166666666666",
#             "http://dbpedia.org/property/sepAvgRecordLowF": "18.1",
#             "http://dbpedia.org/property/febAvgRecordLowF": "-42",
#             "http://dbpedia.org/property/augMeanF": "43.9",
#             "http://dbpedia.org/property/novRecordLowF": "\u221245",
#             "http://schema.org/sameAs": {
#                "__deferred": {
#                   "uri": "http://viaf.org/viaf/156365170"
#                }
#             },
#             "http://dbpedia.org/property/octSnowInch": "8.119999999999999",
#             "http://dbpedia.org/property/augAvgRecordHighF": "71.2",
#             "http://dbpedia.org/property/timezone": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Alaska_Time_Zone"
#                }
#             },
#             "http://dbpedia.org/property/julLowF": "40.6",
#             "http://dbpedia.org/property/aprRecordLowF": "\u221247",
#             "http://dbpedia.org/ontology/thumbnail": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/Deadhorse_Alaska_aerial_view.jpg?width=300"
#                }
#             },
#             "http://dbpedia.org/property/pushpinMapCaption": "Location in the United States of America",
#             "http://dbpedia.org/property/officialName": "Deadhorse, Alaska",
#             "http://dbpedia.org/property/aprLowF": "\u22123.8",
#             "http://dbpedia.org/property/mayAvgRecordHighF": "42.3",
#             "http://dbpedia.org/property/sepSnowInch": "3.11",
#             "http://dbpedia.org/property/novPrecipitationInch": "0.33",
#             "http://dbpedia.org/property/sepLowF": "30.8",
#             "http://dbpedia.org/property/aprSnowInch": "0.79",
#             "http://dbpedia.org/property/marLowF": "\u221220.4",
#             "http://dbpedia.org/property/octMeanF": "18.8",
#             "http://dbpedia.org/property/aprMeanF": "3.3"
#          }
#       ],
#       "__count": "1"
#    }
# }
