# %% [markdown]
# # Lab 1 - API de Acesso a Dados

# %% [markdown]
# # Tarefa 1
#
# Das fontes de dados disponíveis, tente encontrar fontes com formatos diferentes e importá-las via Python. Busque pelo menos dois formatos.

# %%
#Fonte dos dados: https://data.worldbank.org/indicator/EN.ATM.CO2E.KT?end=2018&start=1960&view=chart
import requests
url = "http://api.worldbank.org/v2/country/bra/indicator/EN.ATM.CO2E.KT?end=2018&start=1960"
data = requests.get(url).content
print(data.decode("utf-8"))
# Out:
# ﻿<?xml version="1.0" encoding="utf-8"?>
# <wb:data page="1" pages="2" per_page="50" total="61" sourceid="2" sourcename="World Development Indicators" lastupdated="2021-07-30" xmlns:wb="http://www.worldbank.org">
#   <wb:data>
#     <wb:indicator id="EN.ATM.CO2E.KT">CO2 emissions (kt)</wb:indicator>
#     <wb:country id="BR">Brazil</wb:country>
#     <wb:countryiso3code>BRA</wb:countryiso3code>
#     <wb:date>2020</wb:date>
#     <wb:value />
#     <wb:unit />
#     <wb:obs_status />
#     <wb:decimal>0</wb:decimal>
#   </wb:data>
#   <wb:data>
#     <wb:indicator id="EN.ATM.CO2E.KT">CO2 emissions (kt)</wb:indicator>
#     <wb:country id="BR">Brazil</wb:country>
#     <wb:countryiso3code>BRA</wb:countryiso3code>
#     <wb:date>2019</wb:date>
#     <wb:value />
#     <wb:unit />
#     <wb:obs_status />
#     <wb:decimal>0</wb:decimal>
#   </wb:data>
#   <wb:data>
#     <wb:indicator id="EN.ATM.CO2E.KT">CO2 emissions (kt)</wb:indicator>
#     <wb:country id="BR">Brazil</wb:country>
# ...

# %%
#Fonte dos dados: https://sidra.ibge.gov.br/tabela/8168

import json
import requests
url = "https://servicodados.ibge.gov.br/api/v3/agregados/8168/periodos/2019/variaveis/11671|11672|11673|11674|11675|11676|11677|11678|11679|11680|11681|11682|11683|11684|11685|11686?localidades=N1[all]&classificacao=58[95253]"
data = requests.get(url).content
# print(data.decode("utf-8"))
parsed = json.loads(data)
print(json.dumps(parsed, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "id": "11671",
#         "resultados": [
#             {
#                 "classificacoes": [
#                     {
#                         "categoria": {
#                             "95253": "Total"
#                         },
#                         "id": "58",
#                         "nome": "Grupo de idade"
#                     },
#                     {
#                         "categoria": {
#                             "6794": "Total"
#                         },
#                         "id": "2",
#                         "nome": "Sexo"
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
# ...

# %% [markdown]
# # Tarefa 2
#
# ## Engenharia reversa
#
# Monte um diagramas que representem modelos dos dados que você terá acesso e como pretende associá-los. Coloque abaixo uma imagem do diagrama.
